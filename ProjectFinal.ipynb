# %% [markdown]
# ## Final Project Outline

# %% [markdown]
# ### prepare dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('PlayerData.csv')
k = sqrt(len(df))/2
k
# Out:
# 66.22122016393234

# %%
# randomly select test and train data
train, test = train_test_split(df, test_size=0.7)

# %%
# DATASET WITH 7 FEATURES
X_train_LR7 = train[["Marking", "Standing_Tackle", "Aggression", \
                 "Composure", "Acceleration", "Stamina", "Vision"]].to_numpy()

y_train_LR7 = train[["Rating"]].to_numpy()

X_test_LR7 = test[["Marking", "Standing_Tackle", "Aggression", \
                 "Composure", "Acceleration", "Stamina", "Vision"]].to_numpy()

y_test_LR7 = test[["Rating"]].to_numpy()

# %%
# DATASET WITH 3 FEATURES
X_train_LR3 = train[["Acceleration", "Stamina", "Vision"]].to_numpy()

y_train_LR3 = train[["Rating"]].to_numpy()

X_test_LR3 = test[["Acceleration", "Stamina", "Vision"]].to_numpy()

y_test_LR3 = test[["Rating"]].to_numpy()

# %%
# DATASET WITH 19 FEATURES
X_train_LR19 = train[["Marking", "Standing_Tackle", "Aggression", \
                 "Composure", "Acceleration", "Stamina", "Vision", "Sliding_Tackle",\
                 "Reactions", "Attacking_Position", "Interceptions", "Crossing", "Short_Pass",\
                "Long_Pass", "Speed", "Strength", "Agility", "Jumping", "Heading"]].to_numpy()

y_train_LR19 = train[["Rating"]].to_numpy()

X_test_LR19 = test[["Marking", "Standing_Tackle", "Aggression", \
                 "Composure", "Acceleration", "Stamina", "Vision", "Sliding_Tackle",\
                 "Reactions", "Attacking_Position", "Interceptions", "Crossing", "Short_Pass",\
                "Long_Pass", "Speed", "Strength", "Agility", "Jumping", "Heading"]].to_numpy()

y_test_LR19 = test[["Rating"]].to_numpy()

# %% [markdown]
# ### TRAIN LINEAR REGRESSION

# %%
# Linear Regression - 7 Features
model_LR7 = LinearRegression()
model_LR7.fit(X_train_LR7, y_train_LR7)
intercept_LR7 = model_LR7.intercept_
coeff_LR7 = model_LR7.coef_

y_pred_train_LR7 = model_LR7.predict(X_train_LR7)
y_pred_test_LR7 = model_LR7.predict(X_test_LR7)

rmse_train_LR7 = mean_squared_error(y_train_LR7, y_pred_train_LR7)
rmse_train_LR7 = sqrt(rmse_train_LR7)

rmse_test_LR7 = mean_squared_error(y_test_LR7, y_pred_test_LR7)
rmse_test_LR7 = sqrt(rmse_test_LR7)

r2_train_LR7 = r2_score(y_train_LR7, y_pred_train_LR7)
r2_test_LR7 = r2_score(y_test_LR7, y_pred_test_LR7)

# %%
# Linear Regression - 3 Features
model_LR3 = LinearRegression()
model_LR3.fit(X_train_LR3, y_train_LR3)
intercept_LR3 = model_LR3.intercept_
coeff_LR3 = model_LR3.coef_

y_pred_train_LR3 = model_LR3.predict(X_train_LR3)
y_pred_test_LR3 = model_LR3.predict(X_test_LR3)

rmse_train_LR3 = mean_squared_error(y_train_LR3, y_pred_train_LR3)
rmse_train_LR3 = sqrt(rmse_train_LR3)

rmse_test_LR3 = mean_squared_error(y_test_LR3, y_pred_test_LR3)
rmse_test_LR3 = sqrt(rmse_test_LR3)

r2_train_LR3 = r2_score(y_train_LR3, y_pred_train_LR3)
r2_test_LR3 = r2_score(y_test_LR3, y_pred_test_LR3)

# %%
# Linear Regression - 3 Features
model_LR19 = LinearRegression()
model_LR19.fit(X_train_LR19, y_train_LR19)
intercept_LR19 = model_LR19.intercept_
coeff_LR19 = model_LR19.coef_

y_pred_train_LR19 = model_LR19.predict(X_train_LR19)
y_pred_test_LR19 = model_LR19.predict(X_test_LR19)

rmse_train_LR19 = mean_squared_error(y_train_LR19, y_pred_train_LR19)
rmse_train_LR19 = sqrt(rmse_train_LR19)

rmse_test_LR19 = mean_squared_error(y_test_LR19, y_pred_test_LR19)
rmse_test_LR19 = sqrt(rmse_test_LR19)

r2_train_LR19 = r2_score(y_train_LR19, y_pred_train_LR19)
r2_test_LR19 = r2_score(y_test_LR19, y_pred_test_LR19)

# %%
plt.scatter(y_train_LR7, y_pred_train_LR7)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Train Labels - 7 Features - Lin. Reg.")
plt.show()

# %%
plt.scatter(y_test_LR7, y_pred_test_LR7)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Test Labels - 7 Features - Lin. Reg.")
plt.show()

# %%
plt.scatter(y_train_LR3, y_pred_train_LR3)
plt.xlabel("Actual Player Rating")
plt.ylabel("Predicted Player Rating")
plt.title("Actual vs. Predicted Train Labels - 3 Features - Lin. Reg.")
plt.show()

# %%
plt.scatter(y_test_LR3, y_pred_test_LR3)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Test Labels - 3 Features - Lin. Reg.")
plt.show()

# %%
plt.scatter(y_train_LR19, y_pred_train_LR19)
plt.xlabel("Actual Player Rating")
plt.ylabel("Predicted Player Rating")
plt.title("Actual vs. Predicted Train Labels - 19 Features - Lin. Reg.")
plt.show()

# %%
plt.scatter(y_test_LR19, y_pred_test_LR19)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Train Labels - 19 Features - Lin. Reg.")
plt.show()

# %% [markdown]
# ### TRAIN KNN REGRESSION

# %%
# KNN - 7 features
model_KNN7 = KNeighborsRegressor(n_neighbors=31)
model_KNN7.fit(X_train_LR7, y_train_LR7)

y_pred_train_KNN7 = model_KNN7.predict(X_train_LR7)
y_pred_test_KNN7 = model_KNN7.predict(X_test_LR7)

rmse_train_KNN7 = mean_squared_error(y_train_LR7, y_pred_train_KNN7)
rmse_train_KNN7 = sqrt(rmse_train_LR7)

rmse_test_KNN7 = mean_squared_error(y_test_LR7, y_pred_test_KNN7)
rmse_test_KNN7 = sqrt(rmse_test_KNN7)

r2_train_KNN7 = r2_score(y_train_LR7, y_pred_train_KNN7)
r2_test_KNN7 = r2_score(y_test_LR7, y_pred_test_KNN7)

# %%
# KNN - 3 features
model_KNN3 = KNeighborsRegressor(n_neighbors=31)
model_KNN3.fit(X_train_LR3, y_train_LR3)

y_pred_train_KNN3 = model_KNN3.predict(X_train_LR3)
y_pred_test_KNN3 = model_KNN3.predict(X_test_LR3)

rmse_train_KNN3 = mean_squared_error(y_train_LR3, y_pred_train_KNN3)
rmse_train_KNN3 = sqrt(rmse_train_LR3)

rmse_test_KNN3 = mean_squared_error(y_test_LR3, y_pred_test_KNN3)
rmse_test_KNN3 = sqrt(rmse_test_KNN3)

r2_train_KNN3 = r2_score(y_train_LR3, y_pred_train_KNN3)
r2_test_KNN3 = r2_score(y_test_LR3, y_pred_test_KNN3)

# %%
# KNN - 3 features
model_KNN19 = KNeighborsRegressor(n_neighbors=31)
model_KNN19.fit(X_train_LR19, y_train_LR19)

y_pred_train_KNN19 = model_KNN19.predict(X_train_LR19)
y_pred_test_KNN19 = model_KNN19.predict(X_test_LR19)

rmse_train_KNN19 = mean_squared_error(y_train_LR19, y_pred_train_KNN19)
rmse_train_KNN19 = sqrt(rmse_train_LR19)

rmse_test_KNN19 = mean_squared_error(y_test_LR19, y_pred_test_KNN19)
rmse_test_KNN19 = sqrt(rmse_test_KNN19)

r2_train_KNN19 = r2_score(y_train_LR19, y_pred_train_KNN19)
r2_test_KNN19 = r2_score(y_test_LR19, y_pred_test_KNN19)

# %%
plt.scatter(y_train_LR7, y_pred_train_KNN7, color = "violet")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Train Labels - 7 Features - KNN")
plt.show()

# %%
plt.scatter(y_test_LR7, y_pred_test_KNN7)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Test Labels - 7 Features - KNN")
plt.show()

# %%
plt.scatter(y_train_LR3, y_pred_train_KNN3, color = "violet")
plt.xlabel("Actual Player Rating")
plt.ylabel("Predicted Player Rating")
plt.title("Actual vs. Predicted Train Labels - 3 Features - KNN")
plt.show()

# %%
plt.scatter(y_test_LR3, y_pred_test_KNN3)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Train Labels - 3 Features - KNN")
plt.show()

# %%
plt.scatter(y_train_LR19, y_pred_train_KNN19, color="violet")
plt.xlabel("Actual Player Rating")
plt.ylabel("Predicted Player Rating")
plt.title("Actual vs. Predicted Train Labels - 19 Features - KNN")
plt.show()

# %%
plt.scatter(y_test_LR19, y_pred_test_KNN19)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Train Labels - 19 Features - KNN")
plt.show()

# %% [markdown]
# ### KNN larger k

# %%
# KNN - 7 features - k

model_KNN7 = KNeighborsRegressor(n_neighbors=5)
model_KNN7.fit(X_train_LR7, y_train_LR7)

y_pred_train_KNN7 = model_KNN7.predict(X_train_LR7)
y_pred_test_KNN7 = model_KNN7.predict(X_test_LR7)

rmse_train_KNN7 = mean_squared_error(y_train_LR7, y_pred_train_KNN7)
rmse_train_KNN7 = sqrt(rmse_train_LR7)

rmse_test_KNN7 = mean_squared_error(y_test_LR7, y_pred_test_KNN7)
rmse_test_KNN7 = sqrt(rmse_test_KNN7)

r2_train_KNN7 = r2_score(y_train_LR7, y_pred_train_KNN7)
r2_test_KNN7 = r2_score(y_test_LR7, y_pred_test_KNN7)

# %%
# KNN - 3 features
model_KNN3 = KNeighborsRegressor(n_neighbors=10)
model_KNN3.fit(X_train_LR3, y_train_LR3)

y_pred_train_KNN3 = model_KNN3.predict(X_train_LR3)
y_pred_test_KNN3 = model_KNN3.predict(X_test_LR3)

rmse_train_KNN3 = mean_squared_error(y_train_LR3, y_pred_train_KNN3)
rmse_train_KNN3 = sqrt(rmse_train_LR3)

rmse_test_KNN3 = mean_squared_error(y_test_LR3, y_pred_test_KNN3)
rmse_test_KNN3 = sqrt(rmse_test_KNN3)

r2_train_KNN3 = r2_score(y_train_LR3, y_pred_train_KNN3)
r2_test_KNN3 = r2_score(y_test_LR3, y_pred_test_KNN3)

# %%
# KNN - 3 features
model_KNN19 = KNeighborsRegressor(n_neighbors=10)
model_KNN19.fit(X_train_LR19, y_train_LR19)

y_pred_train_KNN19 = model_KNN19.predict(X_train_LR19)
y_pred_test_KNN19 = model_KNN19.predict(X_test_LR19)

rmse_train_KNN19 = mean_squared_error(y_train_LR19, y_pred_train_KNN19)
rmse_train_KNN19 = sqrt(rmse_train_LR19)

rmse_test_KNN19 = mean_squared_error(y_test_LR19, y_pred_test_KNN19)
rmse_test_KNN19 = sqrt(rmse_test_KNN19)

r2_train_KNN19 = r2_score(y_train_LR19, y_pred_train_KNN19)
r2_test_KNN19 = r2_score(y_test_LR19, y_pred_test_KNN19)

# %%
plt.scatter(y_train_LR7, y_pred_train_KNN7)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Train Labels - 7 Features - KNN")
plt.show()

# %%
plt.scatter(y_test_LR7, y_pred_test_KNN7)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Test Labels - 7 Features - KNN")
plt.show()

# %%
from sklearn.metrics import accuracy_score
# choose k between 1 to 31
k_range = range(1, 101)
mse_scores7 = []
# use iteration to caclulator different k in models, then return the average accuracy based on the cross validation
for k in k_range:
    knn = KNeighborsRegressor(n_neighbors=k)

    knn.fit(X_train_LR7, y_train_LR7)

    y_pred = knn.predict(X_test_LR7)

    mse = mean_squared_error(y_test_LR7, y_pred)
    mse_scores7.append(mse)


# plot to see clearly
plt.plot(k_range, mse_scores7)
plt.xlabel('Value of K for KNN')
plt.ylabel('Mean Squared Error')
plt.title('MSE vs. k for KNN features = 7')
plt.show()

# %%
# choose k between 1 to 31
k_range = range(1, 101)
mse_scores3 = []
# use iteration to caclulator different k in models, then return the average accuracy based on the cross validation
for k in k_range:
    knn = KNeighborsRegressor(n_neighbors=k)

    knn.fit(X_train_LR3, y_train_LR3)

    y_pred = knn.predict(X_test_LR3)

    mse = mean_squared_error(y_test_LR3, y_pred)
    mse_scores3.append(mse)


# plot to see clearly
plt.plot(k_range, mse_scores3)
plt.xlabel('Value of K for KNN')
plt.ylabel('Mean Squared Error')
plt.title('MSE vs. k for KNN features = 3')
plt.show()

# %%
# choose k between 1 to 31
k_range = range(1, 101)
mse_scores19 = []
# use iteration to caclulator different k in models, then return the average accuracy based on the cross validation
for k in k_range:
    knn = KNeighborsRegressor(n_neighbors=k)

    knn.fit(X_train_LR19, y_train_LR19)

    y_pred = knn.predict(X_test_LR19)

    mse = mean_squared_error(y_test_LR19, y_pred)
    mse_scores19.append(mse)


# plot to see clearly
plt.plot(k_range, mse_scores19)
plt.xlabel('Value of K for KNN')
plt.ylabel('Mean Squared Error')
plt.title('MSE vs. k for KNN features = 19')
plt.show()

# %%
# plot to see clearly
plt.plot(k_range, mse_scores3, label = "3 features")
plt.plot(k_range, mse_scores7, label="7 features")
plt.plot(k_range, mse_scores19, label = "19 features")
plt.xlabel('Value of K for KNN')
plt.ylabel('Mean Squared Error')
plt.title('MSE vs. KNN k')
plt.legend()
plt.show()

# %% [markdown]
# ### Compare all values

# %%
# compare RMSE

print("7 FEATURES")
print("LR TRAIN RSME 7 features:", round(rmse_train_LR7,3))
print("LR TEST RSME 7 features:", round(rmse_test_LR7,3))
print("LR TRAIN R2 7 features:", round(r2_train_LR7,3))
print("LR TEST R2 7 features:", round(r2_test_LR7,3))

print("KNN TRAIN RSME 7 features:", round(rmse_train_KNN7,3))
print("KNN TEST RSME 7 features:", round(rmse_test_KNN7,3))
print("KNN TRAIN R2 7 features:", round(r2_train_KNN7,3))
print("KNN TEST R2 7 features:", round(r2_test_KNN7,3))
print("\n")
# Out:
# 7 FEATURES
# LR TRAIN RSME 7 features: 5.473
# LR TEST RSME 7 features: 5.378
# LR TRAIN R2 7 features: 0.405
# LR TEST R2 7 features: 0.417
# KNN TRAIN RSME 7 features: 2.339
# KNN TEST RSME 7 features: 3.667
# KNN TRAIN R2 7 features: 0.812
# KNN TEST R2 7 features: 0.729

# %%
print("3 FEATURES")
print("LR TRAIN RSME 3 features:", round(rmse_train_LR3,3))
print("LR TEST RSME 3 features:", round(rmse_test_LR3,3))
print("LR TRAIN R2 3 features:", round(r2_train_LR3,3))
print("LR TEST R2 3 features:", round(r2_test_LR3,3))

print("KNN TRAIN RSME 3 features:", round(rmse_train_KNN3,3))
print("KNN TEST RSME 3 features:", round(rmse_test_KNN3,3))
print("KNN TRAIN R2 3 features:", round(r2_train_KNN3,3))
print("KNN TEST R2 3 features:", round(r2_test_KNN3,3))
print("\n")
# Out:
# 3 FEATURES
# LR TRAIN RSME 3 features: 6.059
# LR TEST RSME 3 features: 6.001
# LR TRAIN R2 3 features: 0.271
# LR TEST R2 3 features: 0.274
# KNN TRAIN RSME 3 features: 2.462
# KNN TEST RSME 3 features: 5.341
# KNN TRAIN R2 3 features: 0.531
# KNN TEST R2 3 features: 0.425

# %%
print("19 FEATURES")
print("LR TRAIN RSME 19 features:", round(rmse_train_LR19,3))
print("LR TEST RSME 19 features:", round(rmse_test_LR19,3))
print("LR TRAIN R2 19 features:", round(r2_train_LR19,3))
print("LR TEST R2 19 features:", round(r2_test_LR19,3))

print("KNN TRAIN RSME 19 features:", round(rmse_train_KNN19,3))
print("KNN TEST RSME 19 features:", round(rmse_test_KNN19,3))
print("KNN TRAIN R2 19 features:", round(r2_train_KNN19,3))
print("KNN TEST R2 19 features:", round(r2_test_KNN19,3))
print("\n")
# Out:
# 19 FEATURES
# LR TRAIN RSME 19 features: 3.518
# LR TEST RSME 19 features: 3.548
# LR TRAIN R2 19 features: 0.754
# LR TEST R2 19 features: 0.746
# KNN TRAIN RSME 19 features: 1.876
# KNN TEST RSME 19 features: 2.484
# KNN TRAIN R2 19 features: 0.9
# KNN TEST R2 19 features: 0.876

# %%
features = [3,7,19]

LR_trainRSME = [rmse_train_LR3, rmse_train_LR7, rmse_train_LR19]
LR_testRSME = [rmse_test_LR3, rmse_test_LR7, rmse_test_LR19]
KNN_trainRSME = [rmse_train_KNN3, rmse_train_KNN7, rmse_train_KNN19]
KNN_testRSME = [rmse_test_KNN3, rmse_test_KNN7, rmse_test_KNN19]


LR_trainR2 = [r2_train_LR3, r2_train_LR7, r2_train_LR19]
LR_testR2 = [r2_test_LR3, r2_test_LR7, r2_test_LR19]
KNN_trainR2 = [r2_train_KNN3, r2_train_KNN7, r2_train_KNN19]
KNN_testR2 = [r2_test_KNN3, r2_test_KNN7, r2_test_KNN19]

# %%
# features vs RMSE
plt.plot(features, LR_trainRSME, label = "LR Train")
plt.plot(features, LR_testRSME, label = "LR Test")
plt.plot(features, KNN_trainRSME, label = "KNN Train")
plt.plot(features, KNN_testRSME, label = "KNN Test")
plt.xlabel('Num Features')
plt.ylabel('Mean Squared Error')
plt.title('MSE vs. Num Features')
plt.legend()
plt.show()

# %%
# features vs RMSE
plt.plot(features, LR_trainR2, label = "LR Train")
plt.plot(features, LR_testR2, label = "LR Test")
plt.plot(features, KNN_trainR2, label = "KNN Train")
plt.plot(features, KNN_testR2, label = "KNN Test")
plt.xlabel('Num Features')
plt.ylabel('R2 Score')
plt.title('R2 vs. Num Features')
plt.legend()
plt.show()
